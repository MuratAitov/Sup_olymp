# %% [markdown]
# <a href="https://colab.research.google.com/github/MuratAitov/Sup_olymp/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import telebot
from telebot import types
import hashlib
import requests
import wget
import json


client = telebot.TeleBot('5011326661:AAElSEOIiCfEGx2wsjiWp1n2x3Xd-CY4Rhs')
j = ['механико-математический факультет', 'факультет вычислительной математики и кибернетики', 'физический факультет',
     'химический факультет', 'биологический факультет', 'факультет почвоведения', 'геологический факультет',
     'географический факультет', 'факультет наук о материалах', 'факультет фундаментальной медицины',
     'исторический факультет', 'филологический факультет', 'философский факультет', 'экономический факультет',
     'юридический факультет', 'факультет журналистики', 'факультет психологии',
     'факультет иностранных языков и регионоведения', 'факультет биоинженерии и биоинформатики',
     'факультет фундаментальной физико-химической инженерии', 'высшая школа государственного аудита',
     'высшая школа телевидения', 'высшая школа современных социальных наук', 'факультет политологии',
     'факультет государственного управления', 'высшая школа бизнеса', 'факультет мировой политики',
     'московская школа экономики', 'факультет глобальных процессов', 'высшая школа перевода',
     'высшая школа управления и инноваций', 'биотехнологический факультет', 'факультет космических исследований',
     'филиал мгу в г. севастополе']

rotebalslovarya =  {'механико-математический факультет': {'фундаментальные математика и механика': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'всесибирская открытая олимпиада школьников'), (11, 'второй', ' межрегиональная олимпиада школьников на базе ведомственных образовательных организаций'), (11, 'второй', ' объединенная международная математическая олимпиада "формула единства" / "третье тысячелетие"'), (11, 'второй', ' олимпиада «курчатов»'), (11, 'второй', ' олимпиада юношеской математической школы'), (11, 'второй', ' отраслевая физико- математическая олимпиада школьников «росатом»'), (11, 'второй', ' турнир имени м.в. ломоносова'), (11, 'второй', ' межрегиональная олимпиада школьников им.\nи.я. верченко'), (11, 'первой или второй', 'олимпиада школьников "ломоносов"'), (11, 'первой или второй', 'олимпиада школьников "ломоносов"')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'факультет вычислительной математики и кибернетики': {'прикладная математика и информатика': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'фундаментальная информатика и информационные технологии': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'физический факультет': {'фундаментальная и прикладная физика': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'астрономия': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'химический факультет': {'фундаментальная и прикладная химия': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}}, 'биологический факультет': {'биология': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'экология и природопользование': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'олимпиада\nшкольников "ломоносов"')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}}, 'факультет почвоведения': {'почвоведение': {'бви': [(11, 'второй', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}, 'экология и природопользование': {'бви': [(11, 'второй', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}}, 'геологический факультет': {'геология': {'бви': [(11, 'первой', 'олимпиада школьников "ломоносов"')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'всесибирская открытая олимпиада школьников'), (11, 'второй', ' объединённая межвузовская математическая олимпиада школьников'), (11, 'второй', '\nолимпиада курчатов'), (11, 'второй', ' олимпиада школьников\n«физтех»'), (11, 'второй', ' отраслевая физико-\nматематическая олимпиада школьников «росатом»'), (11, 'второй', ' турнир имени м.в. ломоносова')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'олимпиада школьников "ломоносов"'), (11, 'второй', ' всесибирская открытая олимпиада школьников'), (11, 'второй', ' городская открытая олимпиада школьников по физике'), (11, 'второй', ' олимпиада курчатов'), (11, 'второй', ' олимпиада школьников\n«шаг в будущее»'), (11, 'второй', ' олимпиада школьников санкт-петербургского государственного университета'), (11, 'второй', ' турнир имени м.в. ломоносова')]}}, 'географический факультет': {'науки о земле (направления подготовки\n«география»,\n«картография и геоинформатика»,\n«гидрометеорология»,\n«экология и природопользование»)': {'бви': [(10.11, 'первой', 'Все олимпиады перечня')], 'егэ': [(10.11, 'первой', 'Все олимпиады перечня'), (10.11, 'второй', 'Все олимпиады перечня'), (10.11, 'первой или второй', 'Все олимпиады перечня')]}}, 'факультет наук о материалах': {'химия, физика и механика материалов': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'бви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'факультет фундаментальной медицины': {'лечебное дело': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'фармация': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}}, 'исторический факультет': {'история': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'олимпиада школьников «покори воробьевы горы!»'), (11, 'первой', 'олимпиада школьников "ломоносов"')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'олимпиада школьников «покори воробьевы горы!»'), (11, 'первой', 'олимпиада школьников "ломоносов"')]}, 'история искусств': {'егэ': [(11, 'первой', 'Все олимпиады перечня')]}}, 'филологический факультет': {'филология (образовательная программа "русский язык и литература")': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'олимпиада школьников\n«ломоносов»')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', 'Все олимпиады перечня')]}, 'филология (образовательная программа "зарубежная филология")': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'олимпиада школьников\n«ломоносов»')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'олимпиада школьников\n«ломоносов»')]}, 'филология (образовательная программа "славянская и классическая филология")': {'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'олимпиада школьников\n«ломоносов»')]}, 'фундаментальная и прикладная лингвистика': {'егэ': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}}, 'философский факультет': {'философия': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'религиоведение': {'дви': [(11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'олимпиада школьников\n«ломоносов»'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня')], 'егэ': [(11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня')]}, 'культурология': {'бви': [(11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня')], 'дви': [(11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'олимпиада школьников\n«ломоносов»'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня')], 'егэ': [(11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня')]}, 'реклама и связи с общественностью': {'дви': [(11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'олимпиада школьников\n«ломоносов»'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня')], 'егэ': [(11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'первой', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня'), (11.0, 'второй', 'Все олимпиады перечня')]}}, 'экономический факультет': {'экономика': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'второй', 'всесибирская открытая олимпиада школьников'), (11, 'второй', ' объединённая международная математическая олимпиада «формула единства» / «третье тысячелетие»'), (11, 'второй', '  турнир имени м.в.ломоносова')]}, 'менеджмент': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'второй', 'всесибирская открытая олимпиада школьников'), (11, 'второй', ' объединённая международная математическая олимпиада «формула единства» / «третье тысячелетие»'), (11, 'второй', '  турнир имени м.в.ломоносова')]}}, 'юридический факультет': {'юриспруденция': {'бви': [(11, 'первой', 'олимпиада школьников\n«ломоносов»')], 'егэ': [(11, 'первой', 'Все олимпиады перечня')]}}, 'факультет журналистики': {'журналистика': {'бви': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', ' олимпиада школьников\n«покори воробьёвы горы!»')], 'дви': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', ' олимпиада школьников\n«покори воробьёвы горы!»')], 'егэ': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', ' олимпиада школьников\n«покори воробьёвы горы!»')]}, 'медиакоммуникации': {'бви': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', ' олимпиада школьников\n«покори воробьёвы горы!»')], 'дви': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', ' олимпиада школьников\n«покори воробьёвы горы!»')], 'егэ': [(11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', ' олимпиада школьников\n«покори воробьёвы горы!»'), (11, 'первой', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', ' олимпиада школьников\n«покори воробьёвы горы!»')]}}, 'факультет психологии': {'клиническая психология': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня')]}, 'психология служебной деятельности': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня')]}, 'педагогика и психология девиантного поведения': {'дви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня')]}}, 'факультет иностранных языков и регионоведения': {'перевод и переводоведение': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'лингвистика': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'культурология': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'регионоведение россии': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'зарубежное регионоведение': {'бви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}}, 'факультет биоинженерии и биоинформатики': {'биоинженерии и биоинформатика': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}}, 'факультет фундаментальной физико-химической инженерии': {'прикладные математика и физика': {'бви': [(11, 'первой или второй', 'олимпиада школьников\n«ломоносов»')], 'дви': [(11, 'первой или второй', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой или второй', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'фундаментальная и прикладная химия': {'бви': [(11, 'первой или второй', 'олимпиада школьников\n«ломоносов»')], 'дви': [(11, 'первой или второй', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой или второй', 'олимпиада школьников\n«ломоносов»'), (11, 'первой или второй', 'олимпиада школьников\n«ломоносов»'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'высшая школа государственного аудита': {'юриспруденция': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'экономика': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'государственный аудит')]}}, 'высшая школа телевидения': {'телевидение': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'московская олимпиада школьников'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'всероссийская толстовская олимпиада школьников'), (11, 'второй', ' московская олимпиада школьников'), (11, 'второй', ' олимпиада школьников «покори воробьёвы горы!»'), (11, 'второй', ' турнир имени м.в. ломоносова'), (11, 'первой', 'междисциплинарная\nолимпиада школьников\nимени в.и. вернадского'), (11, 'первой', 'Все олимпиады перечня')]}}, 'высшая школа современных социальных наук': {'социология': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'управление персоналом': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'менеджмент': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'факультет политологии': {'политология': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'конфликтология': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'факультет государственного управления': {'государственное и муниципальное управление': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'управление персоналом': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'менеджмент': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'политология': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}}, 'высшая школа бизнеса': {'менеджмент': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'московская олимпиада школьников'), (11, 'второй', ' олимпиада школьников санкт- петербургского государственного университета')]}}, 'факультет мировой политики': {'международные отношения': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'олимпиада школьников "ломоносов"'), (11, 'первой', 'олимпиада школьников санкт- петербургского государственного\nуниверситета'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'олимпиада школьников санкт- петербургского\nгосударственного университета')]}}, 'московская школа экономики': {'экономика': {'бви': [(11, 'первой', 'Все олимпиады перечня')]}}, 'факультет глобальных процессов': {'международные отношения (образовательные программы\n«глобальная экономика и управление»,\n«глобальные политические процессы и дипломатия»)': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'международные отношения (образовательная программа\n«международное гуманитарное сотрудничество»)': {'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'международные отношения (образовательная программа\n«глобальная энергетика и международный бизнес»)': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'бви': [(11, 'первой', 'Все олимпиады перечня')]}}, 'высшая школа перевода': {'перевод и переводоведение': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'лингвистика': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'высшая школа управления и инноваций': {'инноватика': {'бви': [(11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}}, 'биотехнологический факультет': {'биотехнология': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}}, 'факультет космических исследований': {'фундаментальные математика и механика': {'бви': [(11, 'второй', 'олимпиада школьников "ломоносов"')], 'егэ': [(11, 'второй', 'олимпиада школьников "ломоносов"')]}}, 'филиал мгу в г. севастополе': {'прикладная математика и информатика': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'фундаментальная и прикладная физика': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')], 'егэ': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня')]}, 'география': {'дви': [('10, 11', 'первой', 'Все олимпиады перечня'), ('10, 11', 'второй', 'Все олимпиады перечня'), ('10, 11', 'первой или второй', 'Все олимпиады перечня')]}, 'история': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня')]}, 'филология': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}, 'журналистика': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}, 'психология': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}, 'экономика': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}, 'государственное и муниципальное управление': {'дви': [(11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня'), (11, 'первой', 'Все олимпиады перечня'), (11, 'второй', 'Все олимпиады перечня'), (11, 'первой или второй', 'Все олимпиады перечня')]}}}


@client.message_handler(commands=['start'])
def oferta(message):
    klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
    prinimayu = types.KeyboardButton('Принимаю')
    klava.add(prinimayu)
    msg = client.send_message(message.chat.id, 'Нажимая кнопку "Принимаю", вы соглашаетесь с ' '[договором оферты](https://docs.google.com/document/d/1OTtyHTpx_XAUgj5Xpgpc2NU73hTFPpzkMHNqKewc_Ao/edit?usp=sharing)', parse_mode='Markdown', reply_markup=klava)
    client.register_next_step_handler(msg, otv)



def otv(message):
    if message.text == 'Принимаю':
        klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
        prinimayu = types.KeyboardButton('Согласен')
        klava.add(prinimayu)
        msg = client.send_message(message.chat.id, 'Нажимая "Согласен" вы соглашаетесь на обработку ' '[персональных данных](https://docs.google.com/document/d/1zPxY0vY9Mk8k3ZI_HqHgUxmvEqM2FgwTT9ZDYWu6E8A/edit?usp=sharing)', parse_mode='Markdown',reply_markup=klava)
        client.register_next_step_handler(msg, zaebalo)




def m(message):
    klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
    moidost = types.KeyboardButton(text='Мои достижения')
    olimp = types.KeyboardButton(text='Олимпиады')
    opov = types.KeyboardButton(text='Оповещения')

    klava.add(moidost, olimp, opov)
    if message.text == 'Согласен':
        msg = client.send_message(message.chat.id, 'Привет, теперь я твой бот-помощник, спасибо что присоединился/лась в этот чат. Здесь ты сможешь посмотреть свои дипломы, выбрать нужный тебе факультет МГУ и посоветовать олимпиады, которые помогут поступить по БВИ или получить скидку на обучение. Успехов тебе во всём!', reply_markup=klava)
        client.register_next_step_handler(msg, answer)



def answer(message):
    if message.text == 'Олимпиады':
        markup_reply = types.ReplyKeyboardMarkup(resize_keyboard=True)
        for i in range(len(j)):
            q = j[i]
            markup_reply.add(q)

        msg = client.send_message(message.chat.id, 'Выберите желаемый факультет', reply_markup=markup_reply)
        client.register_next_step_handler(msg, napravl)
    elif message.text == 'Мои достижения':
        klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
        dip = types.KeyboardButton('Мои дипломы')
        ege = types.KeyboardButton('Результаты ЕГЭ')
        soch = types.KeyboardButton('Результаты сочинения')
        klava.add(dip, ege, soch)
        msg = client.send_message(message.chat.id, 'Здесь вы можете получить свой диплом перечневой олимпиады в формате pdf, узнать результаты по егэ и декабрьскому сочинению', reply_markup=klava)
        client.register_next_step_handler(msg, dost)
    elif message.text == 'Оповещения':
        msg = client.send_message(message.chat.id,'Если вы хотите получать оповещения о ближайших олимпиадах, а также множество полезной информации, то вам следует подписаться на наше сообщество.Сделать вы это можете перейдя по ссылке : https://t.me/sup_olimp')
        client.register_next_step_handler(msg, answer)

def dost(message):
    if message.text == 'Мои дипломы':
        client.send_message(message.chat.id, 'Введите ваши данные в  формате: Фамилия Имя Отчество гг-мм-дд')
        msg = client.send_message(message.chat.id, 'Пример - Аитов Мурат Гамидович 2003-01-08')
        client.register_next_step_handler(msg, grisha)

    elif message.text == 'Результаты ЕГЭ':
        klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
        moidost = types.KeyboardButton(text='Мои достижения')
        olimp = types.KeyboardButton(text='Олимпиады')
        opov = types.KeyboardButton(text='Оповещения')

        klava.add(moidost, olimp, opov)
        msg = client.send_message(message.chat.id,
                                  'Так как егэ еще не скоро, мы решили нацелить все свои силы на другие функции бота, так, что эта функция будет доступна позже🌚',
                                  reply_markup=klava)
        client.register_next_step_handler(msg, answer)
    elif message.text == 'Результаты сочинения':
        klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
        moidost = types.KeyboardButton(text='Мои достижения')
        olimp = types.KeyboardButton(text='Олимпиады')
        opov = types.KeyboardButton(text='Оповещения')

        klava.add(moidost, olimp, opov)
        msg = client.send_message(message.chat.id,
                                  'К сожалению данная функция находится в разарботке, вернитесь позже 🌚',
                                  reply_markup=klava)
        client.register_next_step_handler(msg, answer)


def grisha(message):
    chat_id = message.chat.id
    if __name__ == '__main__':
        fio_date = message.text
        diplom(fio_date, chat_id)


def person_code(info):
    lnk1 = "https://diploma.rsr-olymp.ru/files/rsosh-diplomas-static/compiled-storage-2021/by-person-released/"
    hash_info = hashlib.sha256(info.encode("utf-8")).hexdigest()
    lnk2 = "/codes.js"
    req = lnk1 + hash_info + lnk2
    rq = requests.get(req)
    # a = json.loads(rq.content)
    rqs = str(rq.content)
    return rqs[26:rqs.find("oa")-2]

def get_pdf_link(pc, id):
    lnk1 = "https://diploma.rsr-olymp.ru/files/rsosh-diplomas-static/compiled-storage-2021/by-code/"
    lnk2 = "/color.pdf"
    req = lnk1+pc+lnk2
    klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
    moidost = types.KeyboardButton(text='Мои достижения')
    olimp = types.KeyboardButton(text='Олимпиады')
    opov = types.KeyboardButton(text='Оповещения')

    klava.add(moidost, olimp, opov)
    msg = client.send_message(id, req, reply_markup=klava)
    client.register_next_step_handler(msg, answer)

def diplom(fio_date, id):
    get_pdf_link(person_code(fio_date), id)


def tikaem(message):
    klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
    moidost = types.KeyboardButton(text='Мои достижения')
    olimp = types.KeyboardButton(text='Олимпиады')
    opov = types.KeyboardButton(text='Оповещения')

    klava.add(moidost, olimp, opov)
    msg = client.send_message(message.chat.id, 'qq', reply_markup=klava)
    client.register_next_step_handler(msg, answer)

def napravl(message):
    f = message.text
    k = types.ReplyKeyboardMarkup(resize_keyboard=True)
    for i in j:
        if message.text == i:
            z = rotebalslovarya[i].keys()
            q = list(z)
            for w in q:
                k.add(w)

            msg = client.send_message(message.chat.id, 'Выберите направление', reply_markup=k)
            client.register_next_step_handler(msg,bvi,f)


def bvi(message,fak):
    klava = types.ReplyKeyboardMarkup(resize_keyboard=True)
    moidost = types.KeyboardButton(text='Мои достижения')
    olimp = types.KeyboardButton(text='Олимпиады')
    opov = types.KeyboardButton(text='Оповещения')
    klava.add(moidost, olimp, opov)
    u = message.text
    bv = 'Для БВИ : '

    dv = 'Для максимального балла ДВИ : '
    s = rotebalslovarya[fak][u].keys()
    s1 = list(s)
    if s1[0] == 'бви':
        za = rotebalslovarya[fak][u]['бви']
        for w in range(len(za)):
            za = rotebalslovarya[fak][u]['бви'][w]
            lupa = list(za)
            step = lupa[1]
            olim = lupa[2]
            bv += olim + ' ' + step + ' степени; '
    else:
        bv += 'Нет возможности поступить по бви; '
    if len(s1)>1:
        if s1[1] == 'дви' or s1[0] == 'дви':
            za1 = rotebalslovarya[fak][u]['дви']
            for w in range(len(za1)):
                za1 = rotebalslovarya[fak][u]['дви'][w]
                lupa1 = list(za1)
                step1 = lupa1[1]
                olim1 = lupa1[2]
                dv += olim1 + ' ' + step1 + ' степени; '



    ehali = bv + dv
    client.send_message(message.chat.id,'[Общий перечень олимпиад](https://yadi.sk/i/FH7LieGnPIgaAw)', parse_mode='Markdown')

    msg = client.send_message(message.chat.id, ehali, reply_markup=klava)
    client.register_next_step_handler(msg, answer)






client.polling(none_stop=True, interval=0)
